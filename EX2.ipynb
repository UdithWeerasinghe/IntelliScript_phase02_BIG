# %% [markdown]
# <a href="https://colab.research.google.com/github/UdithWeerasinghe/IntelliScript_phase02_BIG/blob/main/EX2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Required Installation
# %%capture
# !pip install -q -U pandas matplotlib seaborn requests scikit-learn
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q -U trl
# !pip install -q -U auto-gptq
# !pip install -q -U optimum
# !pip install -q -U einops
# !pip install -q -U bitsandbytes
# !pip install -q -U sentence-transformers
# !pip install llama-index llama-parse

# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from llama_index.llms.openai import OpenAI
from llama_index.core import VectorStoreIndex
from llama_parse import LlamaParse
from llama_index.core.node_parser import MarkdownElementNodeParser
from IPython.display import Markdown
import nest_asyncio

# %%
# Hugging Face authentication
from huggingface_hub import login
login("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")

# %%
# Enable async code execution in Colab
nest_asyncio.apply()

# Load the LLaMA 3 model
model_name = "meta-llama/Meta-Llama-3-8B-Instruct"
device = "cuda"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto",
    quantization_config=BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4",
    ),
)
tokenizer = AutoTokenizer.from_pretrained(model_name)


# LlamaParse Setup
parser = LlamaParse(
    api_key="llx-99Y3TlqtF5fjAZYcwx1LvvqXEAveRFl2xWb9p1b3Wluuk69U",
    result_type="markdown",
)
# Out:
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]

# %%
# # HuggingFace Model Setup
# model_name = "meta-llama/Llama-2-7b-hf"  # Replace with your desired HuggingFace model

# device = "cuda" if torch.cuda.is_available() else "cpu"
# model = AutoModelForCausalLM.from_pretrained(
#     model_name,
#     device_map="auto",
#     torch_dtype=torch.float16,
#     quantization_config={"bits": 8},
# )
# tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
# Function to Query HuggingFace Model
def query_huggingface_model(prompt, max_length=200):
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    outputs = model.generate(
        **inputs,
        max_length=max_length,
        num_return_sequences=1,
        do_sample=True,
        temperature=0.7,
    )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)


# Recursive Retrieval Workflow
# Ensure LLMs are explicitly set to None
def recursive_retrieval_workflow(data_folder):
    """
    Processes Excel files in the provided folder, extracts relevant information,
    and creates a recursive retrieval index for querying.

    Parameters:
        data_folder (str): Path to the Google Drive folder containing Excel files.

    Returns:
        query_engine (VectorStoreIndex): Query engine for querying the data.
    """
    # Find Excel files in the directory
    excel_files = []
    for root, _, files in os.walk(data_folder):
        for file in files:
            if file.endswith(('.xlsx', '.xls')):
                excel_files.append(os.path.join(root, file))

    if not excel_files:
        raise ValueError("No Excel files found in the directory.")

    # Parse documents with LlamaParse
    documents = []
    for file_path in excel_files:
        documents.extend(parser.load_data(file_path))

    # Parse the documents into nodes
    node_parser = MarkdownElementNodeParser(llm=None, num_workers=4)  # No LLM dependency
    nodes = node_parser.get_nodes_from_documents(documents)
    base_nodes, objects = node_parser.get_nodes_and_objects(nodes)

    # Build Recursive Retrieval Index
    recursive_index = VectorStoreIndex(nodes=base_nodes + objects, llm=None)  # No LLM dependency

    return recursive_index


# Query Execution
def execute_query(index, query):
    """
    Executes a query using the provided recursive retrieval index.

    Parameters:
        index (VectorStoreIndex): Query index.
        query (str): User query.

    Returns:
        response (str): Response from the HuggingFace model.
    """
    # Retrieve relevant nodes
    retrieved_nodes = index.query(query, similarity_top_k=5)

    # Combine node contents and query the HuggingFace model
    context = "\n".join([node.get_content() for node in retrieved_nodes])
    prompt = f"Context:\n{context}\n\nQuestion: {query}\nAnswer:"
    return query_huggingface_model(prompt)

# %%
# Main Execution
data_folder = '/content/drive/MyDrive/CBSL-data'
query_engines = recursive_retrieval_workflow(data_folder)
# Out:
# Started parsing the file under job_id eab247da-0802-4649-954d-2ba7b8239f67
# Started parsing the file under job_id 3d3f58bd-e745-4353-a6fe-a952de7a142f
# Started parsing the file under job_id bbf723cb-d0eb-4ed7-a609-a728ae8996b1
# Started parsing the file under job_id ef6c9d2e-db0d-48e3-903e-1ceb20356dbd
# Started parsing the file under job_id 094acb62-bee5-44ea-b58f-49e390420530
# Started parsing the file under job_id 743d29c1-cca1-43e6-b83c-39416986cfb8
# Started parsing the file under job_id eeed6bd8-2c19-491e-9130-21cd74d0eac8
# Started parsing the file under job_id 208c1bfb-2502-445d-8ca8-09736575dd0b
# Started parsing the file under job_id 22d7c854-8d00-4986-b589-20bb15f4f718
# Started parsing the file under job_id 91f7f1ba-0467-4c38-a338-52cb6d7c399f
# Started parsing the file under job_id 8ce5adc4-77f3-4ce0-aa0d-6aa52edd54b6
# Started parsing the file under job_id 2bc36938-69ce-4296-9f2b-5a9df59d1ad9
# Started parsing the file under job_id 677d7c9c-9395-42e7-83e1-fa15465a12b3
# Started parsing the file under job_id c0f409e0-6ea9-4c7e-8927-122da895ccaf
# Started parsing the file under job_id 2e31dd05-2574-4e5a-89f9-ea248930fc4a
# Started parsing the file under job_id 5bbc0644-c416-4f22-a5c7-35b5507eaa55
# Started parsing the file under job_id 2218a493-b085-4ea6-9381-0358d931038c
# Started parsing the file under job_id 62c49836-e7ad-4566-a34b-0ac197fe2934
# Started parsing the file under job_id 7fb26963-4f6c-461e-9341-dbc47d85e41b
# Started parsing the file under job_id 7273dd27-3e6a-435a-a33d-e68e2de35443
# Started parsing the file under job_id efbea3f6-0c7b-4d3b-b264-3e13d9655c0c
# Started parsing the file under job_id 550f10e5-0720-4bb8-82c1-011b0a1fe8bf
# Started parsing the file under job_id 79710351-47d3-43e0-ae62-c6ded46076c0
# Started parsing the file under job_id 4a4801f6-6fdb-4946-a3ea-7d47dac2eb25
# Started parsing the file under job_id b4f2e179-f595-4124-b47a-63f950b8ee16
# Started parsing the file under job_id 20d020b0-6f4c-47eb-b346-c924f6b5b540
# Started parsing the file under job_id a6efa856-c116-40d9-b72f-9c8ebdc1b800
# Started parsing the file under job_id fbb1a7b2-7f22-49de-9f13-88a3e8942613
# Started parsing the file under job_id 05308b34-ffb2-4735-8652-2edaa3431a54
# Started parsing the file under job_id b0275aa3-415c-4cc1-b51a-8c5348de4649
# Started parsing the file under job_id 53681877-a7f2-4ee3-bad4-b0b9a672149e
# Started parsing the file under job_id 831761f3-3db4-445c-a0d4-e86714faae63
# Started parsing the file under job_id 74e39916-ccba-43df-9207-9e03fb5e07c1
# Started parsing the file under job_id edefe4a5-9a8e-462a-a550-d738be4bc436
# Started parsing the file under job_id 90843909-995a-429f-b3e0-597afd6e77e2
# Started parsing the file under job_id 0b7724ed-49e8-4446-8a26-d3e019d6b4f9
# Started parsing the file under job_id 19f3a4df-b7a8-400a-9574-05c040316c3f
# Started parsing the file under job_id 6b117141-3906-46c8-a918-091bac6e1121
# Started parsing the file under job_id 08c4dbe0-43ba-4479-83a6-7f1d97b61da7
# Started parsing the file under job_id 747be3ab-88cc-4f45-b009-d838af84e98b
# Started parsing the file under job_id 61f1cd07-47d0-46a7-8122-70d458573e6d
# Started parsing the file under job_id 8fb1ca8a-5b81-4263-9189-92d7722e83f2
# Started parsing the file under job_id 6274903d-832d-4cfb-b8e7-9a4c3b89fcd1
# Started parsing the file under job_id 5ea11546-71a6-48b9-8e7a-272f5e035eb3
# Started parsing the file under job_id bfa4fe54-90ca-40fe-adcf-3e57811a8f91
# Started parsing the file under job_id 2d592f86-0329-4e0e-98ca-40f7269cc877
# Started parsing the file under job_id 6f52068e-f0e4-421e-beab-d1882b4ec4af
# Started parsing the file under job_id 3cf763e0-917f-4fe7-a00b-0764d8cd1d27
# Started parsing the file under job_id b860d4de-6a4b-4eac-a873-5e29c34a0e24
# Started parsing the file under job_id 873edcda-23ad-4925-a217-fac156449cda
# Started parsing the file under job_id 3b4011cd-38d2-4e29-96ce-88df1a39ae9b
# Started parsing the file under job_id 9838565c-314d-4121-8099-dc9b0428a66d
# Started parsing the file under job_id bd87b0ff-4a9b-48e5-b1b7-19a23c83ea73
# Started parsing the file under job_id a3fa7463-1a8c-4103-9055-4536b70a4ea2
# Started parsing the file under job_id 4e239d00-b262-4d84-a9bc-353ae5b60758
# Started parsing the file under job_id 117503f4-7015-4035-a539-a4030a6e4d38
# Started parsing the file under job_id 57950833-1c8f-4349-a079-888ce12f18f2
# Started parsing the file under job_id ac55d99a-ba62-4267-b045-68548f24c59d
# Started parsing the file under job_id b4ede85d-2516-4ab1-b8c3-7f879ee84227
# Started parsing the file under job_id ca967f6a-c2bb-4751-a47a-544178185376
# Started parsing the file under job_id 2120c1ba-8fd9-4d41-8c2a-30695324abf3
# Started parsing the file under job_id 5e188083-7125-4b79-aa44-89e410e49fd5
# Started parsing the file under job_id a73e6954-84a5-4e0c-b92e-07c3369931fa
# Started parsing the file under job_id 4e90af26-912c-4610-9875-bc353f49a219
# Started parsing the file under job_id 48d4a53b-b63c-4ffe-9d52-1595f935a1cc
# Started parsing the file under job_id b4629941-52f7-4bf2-aa61-4f7d41bb6d62
# Started parsing the file under job_id e4706f1b-9e99-480c-91a3-f0dcac048bfb
# Started parsing the file under job_id 1b5997eb-e3a0-44c6-88ce-6801bbe9d7f6
# Started parsing the file under job_id 097536cc-39cc-4695-85fb-f16ec7fa54d1
# Started parsing the file under job_id f017c9bf-d3d4-4426-ad93-75c189fcacf5
# Started parsing the file under job_id f5f45ba9-be69-47d4-88ed-c6f7cf49eeb5
# Started parsing the file under job_id b9c5353a-dfc4-46b1-85e3-0f0dd1f4e7bd
# Started parsing the file under job_id 4e76ca78-9533-46ef-b046-c577f2b7973b
# Started parsing the file under job_id 0d7cb15d-cb27-40f7-bd85-bf2280dc31eb
# Started parsing the file under job_id d8a5fbd4-e9eb-4df5-8ea5-f1374df6db30
# Started parsing the file under job_id 04be86bd-f644-4492-855b-dd2f9f42f24b
# Started parsing the file under job_id 249284ce-2342-4391-82e5-9b38e5b28f3b
# Started parsing the file under job_id a376af8a-f5e8-40f6-ab6d-7732bdbd6d3e
# Started parsing the file under job_id a47779b9-d308-44d4-b743-40f38551f5cc
# Started parsing the file under job_id 254be5f7-f93a-4e5b-b672-6de1b220ba77
# Started parsing the file under job_id ab215932-46c2-432c-8869-20fd9abe6bf0
# Started parsing the file under job_id 0cb2ba93-41c2-4b8a-96d3-1295da7644bf
# Started parsing the file under job_id db76ccac-f9ef-449a-bf9d-41dd1ae7ecbc
# Started parsing the file under job_id c6dee0d9-7da6-4192-8e58-8eb35b1c98fe
# Started parsing the file under job_id 446e90eb-bdf4-43db-94cb-da8fdb2eb9d7
# Started parsing the file under job_id afde2827-a1e7-4ff5-81a9-ed5d2a998a8b
# Started parsing the file under job_id 38c784bc-c34e-465b-b1ad-f5cc53302e66
# Started parsing the file under job_id faa1c627-e072-4fe5-9bab-222a26c39d07
# Started parsing the file under job_id d598c44e-2583-428a-940b-0e90d371b3bd
# Started parsing the file under job_id cfa6ce50-2207-438a-b556-1c2002525288
# Started parsing the file under job_id bdb1220d-6593-4871-9740-17c9475e0ac6
# 1it [00:00, 1486.81it/s]
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-14-4e916e1b166e> in <cell line: 3>()
#       1 # Main Execution
#       2 data_folder = '/content/drive/MyDrive/CBSL-data'
# ----> 3 query_engines = recursive_retrieval_workflow(data_folder)
#
# <ipython-input-13-5103804f72a4> in recursive_retrieval_workflow(data_folder)
#      42     # Parse the documents into nodes
#      43     node_parser = MarkdownElementNodeParser(llm=None, num_workers=4)  # No LLM dependency
# ---> 44     nodes = node_parser.get_nodes_from_documents(documents)
#      45     base_nodes, objects = node_parser.get_nodes_and_objects(nodes)
#      46
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/node_parser/interface.py in get_nodes_from_documents(self, documents, show_progress, **kwargs)
#     163             CBEventType.NODE_PARSING, payload={EventPayload.DOCUMENTS: documents}
#     164         ) as event:
# --> 165             nodes = self._parse_nodes(documents, show_progress=show_progress, **kwargs)
#     166             nodes = self._postprocess_parsed_nodes(nodes, doc_id_to_document)
#     167
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     319
#     320             try:
# --> 321                 result = func(*args, **kwargs)
#     322                 if isinstance(result, asyncio.Future):
#     323                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/node_parser/relational/base_element.py in _parse_nodes(self, nodes, show_progress, **kwargs)
#     125
#     126         for node in nodes_with_progress:
# --> 127             nodes = self.get_nodes_from_node(node)
#     128             all_nodes.extend(nodes)
#     129
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     319
#     320             try:
# --> 321                 result = func(*args, **kwargs)
#     322                 if isinstance(result, asyncio.Future):
#     323                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/node_parser/relational/markdown_element.py in get_nodes_from_node(self, node)
#      28         table_elements = self.get_table_elements(elements)
#      29         # extract summaries over table elements
# ---> 30         self.extract_table_summaries(table_elements)
#      31         # convert into nodes
#      32         # will return a list of Nodes and Index Nodes
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/node_parser/relational/base_element.py in extract_table_summaries(self, elements)
#     214         ]
#     215         summary_co = run_jobs(summary_jobs, workers=self.num_workers)
# --> 216         summary_outputs = asyncio_run(summary_co)
#     217         for element, summary_output in zip(elements, summary_outputs):
#     218             element.table_output = summary_output
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/async_utils.py in asyncio_run(coro)
#      31
#      32         # If we're here, there's an existing loop but it's not running
# ---> 33         return loop.run_until_complete(coro)
#      34
#      35     except RuntimeError as e:
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in run_until_complete(self, future)
#      96                 raise RuntimeError(
#      97                     'Event loop stopped before Future completed.')
# ---> 98             return f.result()
#      99
#     100     def _run_once(self):
#
# /usr/lib/python3.10/asyncio/futures.py in result(self)
#     199         self.__log_traceback = False
#     200         if self._exception is not None:
# --> 201             raise self._exception.with_traceback(self._exception_tb)
#     202         return self._result
#     203
#
# /usr/lib/python3.10/asyncio/tasks.py in __step(***failed resolving arguments***)
#     232                 result = coro.send(None)
#     233             else:
# --> 234                 result = coro.throw(exc)
#     235         except StopIteration as exc:
#     236             if self._must_cancel:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/async_utils.py in run_jobs(jobs, show_progress, workers, desc)
#     146         results = await tqdm_asyncio.gather(*pool_jobs, desc=desc)
#     147     else:
# --> 148         results = await asyncio.gather(*pool_jobs)
#     149
#     150     return results
#
# /usr/lib/python3.10/asyncio/tasks.py in __wakeup(self, future)
#     302     def __wakeup(self, future):
#     303         try:
# --> 304             future.result()
#     305         except BaseException as exc:
#     306             # This may also be a cancellation.
#
# /usr/lib/python3.10/asyncio/tasks.py in __step(***failed resolving arguments***)
#     230                 # We use the `send` method directly, because coroutines
#     231                 # don't have `__iter__` and `__next__` methods.
# --> 232                 result = coro.send(None)
#     233             else:
#     234                 result = coro.throw(exc)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/async_utils.py in worker(job)
#     137     async def worker(job: Coroutine) -> Any:
#     138         async with semaphore:
# --> 139             return await job
#     140
#     141     pool_jobs = [worker(job) for job in jobs]
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/node_parser/relational/base_element.py in _get_table_output(table_context, summary_query_str)
#     197             query_engine = index.as_query_engine(llm=llm, output_cls=TableOutput)
#     198             try:
# --> 199                 response = await query_engine.aquery(summary_query_str)
#     200                 if isinstance(response, PydanticResponse):
#     201                     return response.response
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/base/base_query_engine.py in aquery(self, str_or_query_bundle)
#      62             if isinstance(str_or_query_bundle, str):
#      63                 str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 64             query_result = await self._aquery(str_or_query_bundle)
#      65         dispatcher.event(
#      66             QueryEndEvent(query=str_or_query_bundle, response=query_result)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/query_engine/retriever_query_engine.py in _aquery(self, query_bundle)
#     193             nodes = await self.aretrieve(query_bundle)
#     194
# --> 195             response = await self._response_synthesizer.asynthesize(
#     196                 query=query_bundle,
#     197                 nodes=nodes,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/base.py in asynthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     304             payload={EventPayload.QUERY_STR: query.query_str},
#     305         ) as event:
# --> 306             response_str = await self.aget_response(
#     307                 query_str=query.query_str,
#     308                 text_chunks=[
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/compact_and_refine.py in aget_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      21     ) -> RESPONSE_TEXT_TYPE:
#      22         compact_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 23         return await super().aget_response(
#      24             query_str=query_str,
#      25             text_chunks=compact_texts,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py in aget_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     364                 # if this is the first chunk, and text chunk already
#     365                 # is an answer, then return it
# --> 366                 response = await self._agive_response_single(
#     367                     query_str, text_chunk, **response_kwargs
#     368                 )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py in _agive_response_single(self, query_str, text_chunk, **response_kwargs)
#     485             if response is None and not self._streaming:
#     486                 try:
# --> 487                     structured_response = await program.acall(
#     488                         context_str=cur_text_chunk,
#     489                         **response_kwargs,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py in acall(self, *args, **kwds)
#      91     async def acall(self, *args: Any, **kwds: Any) -> StructuredRefineResponse:
#      92         if self._output_cls is not None:
# ---> 93             answer = await self._llm.astructured_predict(  # type: ignore
#      94                 self._output_cls,
#      95                 self._prompt,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/llms/openai/base.py in astructured_predict(self, llm_kwargs, *args, **kwargs)
#     960         # by default structured prediction uses function calling to extract structured outputs
#     961         # here we force tool_choice to be required
# --> 962         return await super().astructured_predict(*args, llm_kwargs=llm_kwargs, **kwargs)
#     963
#     964     @dispatcher.span
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py in astructured_predict(self, output_cls, prompt, llm_kwargs, **prompt_args)
#     429         )
#     430
# --> 431         result = await program.acall(llm_kwargs=llm_kwargs, **prompt_args)
#     432         dispatcher.event(LLMStructuredPredictEndEvent(output=result))
#     433         return result
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/program/function_program.py in acall(self, llm_kwargs, *args, **kwargs)
#     176         tool = get_function_tool(self._output_cls)
#     177
# --> 178         agent_response = await self._llm.apredict_and_call(
#     179             [tool],
#     180             chat_history=self._prompt.format_messages(llm=self._llm, **kwargs),
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/llms/function_calling.py in apredict_and_call(self, tools, user_msg, chat_history, verbose, allow_parallel_tool_calls, error_on_no_tool_call, **kwargs)
#     236             )
#     237
# --> 238         response = await self.achat_with_tools(
#     239             tools,
#     240             user_msg=user_msg,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/llms/function_calling.py in achat_with_tools(self, tools, user_msg, chat_history, verbose, allow_parallel_tool_calls, **kwargs)
#      71             **kwargs,
#      72         )
# ---> 73         response = await self.achat(**chat_kwargs)
#      74         return self._validate_chat_with_tools_response(
#      75             response,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/llms/callbacks.py in wrapped_async_llm_chat(_self, messages, **kwargs)
#      73                 )
#      74                 try:
# ---> 75                     f_return_val = await f(_self, messages, **kwargs)
#      76                 except BaseException as e:
#      77                     callback_manager.on_event_end(
#
# /usr/local/lib/python3.10/dist-packages/llama_index/llms/openai/base.py in achat(self, messages, **kwargs)
#     631         else:
#     632             achat_fn = acompletion_to_chat_decorator(self._acomplete)
# --> 633         return await achat_fn(messages, **kwargs)
#     634
#     635     @llm_chat_callback()
#
# /usr/local/lib/python3.10/dist-packages/tenacity/asyncio/__init__.py in async_wrapped(*args, **kwargs)
#     187             copy = self.copy()
#     188             async_wrapped.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 189             return await copy(fn, *args, **kwargs)
#     190
#     191         # Preserve attributes
#
# /usr/local/lib/python3.10/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     109         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     110         while True:
# --> 111             do = await self.iter(retry_state=retry_state)
#     112             if isinstance(do, DoAttempt):
#     113                 try:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/asyncio/__init__.py in iter(self, retry_state)
#     151         result = None
#     152         for action in self.iter_state.actions:
# --> 153             result = await action(retry_state)
#     154         return result
#     155
#
# /usr/local/lib/python3.10/dist-packages/tenacity/_utils.py in inner(*args, **kwargs)
#      97
#      98     async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# ---> 99         return call(*args, **kwargs)
#     100
#     101     return inner
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     396     def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398             self._add_action_func(lambda rs: rs.outcome.result())
#     399             return
#     400
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     449                     raise CancelledError()
#     450                 elif self._state == FINISHED:
# --> 451                     return self.__get_result()
#     452
#     453                 self._condition.wait(timeout)
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __get_result(self)
#     401         if self._exception:
#     402             try:
# --> 403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.10/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     112             if isinstance(do, DoAttempt):
#     113                 try:
# --> 114                     result = await fn(*args, **kwargs)
#     115                 except BaseException:  # noqa: B902
#     116                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.10/dist-packages/llama_index/llms/openai/base.py in _achat(self, messages, **kwargs)
#     681
#     682         if self.reuse_client:
# --> 683             response = await aclient.chat.completions.create(
#     684                 messages=message_dicts, stream=False, **self._get_model_kwargs(**kwargs)
#     685             )
#
# /usr/local/lib/python3.10/dist-packages/openai/resources/chat/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#    1718     ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    1719         validate_response_format(response_format)
# -> 1720         return await self._post(
#    1721             "/chat/completions",
#    1722             body=await async_maybe_transform(
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1841             method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1842         )
# -> 1843         return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#    1844
#    1845     async def patch(
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1535             retries_taken = 0
#    1536
# -> 1537         return await self._request(
#    1538             cast_to=cast_to,
#    1539             options=options,
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1636
#    1637             log.debug("Re-raising status error")
# -> 1638             raise self._make_status_error_from_response(err.response) from None
#    1639
#    1640         return await self._process_response(
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: b08022d0********************025d. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
# Example Query
query = "Give date and value pairs for tea export data from 2007 to 2023?"
responses = execute_query(query_engines, query)

# %%
# Display Responses
for engine_name, response in responses.items():
    print(f"----------------------RESPONSE WITH {engine_name.upper()}----------------------")
    display(Markdown(f"{response}"))
